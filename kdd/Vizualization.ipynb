# %%
import seaborn as sns
import csv
import pandas as pd
from pandas import DataFrame
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# repair level 0.0
original_data = pd.read_csv('RicciDataMod.csv')
#print(original_data.select_dtypes(exclude=['object']).dtypes)
#print(original_data.columns)
protected = np.unique(original_data['Race'])
#print(protected)
for col in original_data.select_dtypes(exclude=['object']).columns:
    plt.figure()
    for p in protected:
        oral_w = original_data[original_data['Race'] == p][col]
        sns.distplot(oral_w, label = p)
    plt.legend()

# %%
# script repair level 1.0
original_data = pd.read_csv('RicciResults.current_all.csv')
#print(original_data.select_dtypes(exclude=['object']).dtypes)
#print(original_data.columns)
protected = np.unique(original_data['Race'])
#print(protected)
for col in original_data.select_dtypes(exclude=['object']).columns:
    plt.figure()
    for p in protected:
        oral_w = original_data[original_data['Race'] == p][col]
        sns.distplot(oral_w, label = p)
    plt.legend()

# %%
# actual repair 1.0
original_data = pd.read_csv('RicciRepaired1.0.orig_all.csv')
#print(original_data.select_dtypes(exclude=['object']).dtypes)
#print(original_data.columns)
protected = np.unique(original_data['Race'])
#print(protected)
for col in original_data.select_dtypes(exclude=['object']).columns:
    plt.figure()
    for p in protected:
        oral_w = original_data[original_data['Race'] == p][col]
        sns.distplot(oral_w, label = p)
    plt.legend()

# %%
# audit repair 1.0
original_data = pd.read_csv('RicciRepaired1.0.audits_all.csv')
#print(original_data.select_dtypes(exclude=['object']).dtypes)
#print(original_data.columns)
protected = np.unique(original_data['Race'])
#print(protected)
for col in original_data.select_dtypes(exclude=['object']).columns:
    plt.figure()
    for p in protected:
        oral_w = original_data[original_data['Race'] == p][col]
        sns.distplot(oral_w, label = p)
    plt.legend()
